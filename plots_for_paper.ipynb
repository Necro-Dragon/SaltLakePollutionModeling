# %% [markdown]
# # ReadMe
#
# This notebook is for the generation of all the graphics to use for our paper.

# %%
import numpy as np
import calendar

# %% [markdown]
# ## Graphic 1:  <TYPE>

# %%
avgs = []
for year in [
    "2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009",
    "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019",
    "2020", "2021", "2022", "2023", "2024"
]:
    print(year)
    for i in range(12):
        month = i + 1
        if month < 10:
            month_str = f"0{month}"
        else:
            month_str = f"{month}"

        end_days = calendar.monthrange(int(year), month)[1]
        _, pm10_recordings = load_windspeed_and_pm10(f"{year}-{month_str}-01", f"{year}-{month_str}-{end_days}")
        avgs.append(np.average(pm10_recordings))

for i in range(9):
    month = i + 1
    if month < 10:
        month_str = f"0{month}"
    else:
        month_str = f"{month}"

    end_days = calendar.monthrange(int(year), month)[1]
    _, pm10_recordings = load_windspeed_and_pm10(f"{year}-{month_str}-01", f"{year}-{month_str}-{end_days}")
    avgs.append(np.average(pm10_recordings))
    
plt.plot(np.arange(len(avgs)), avgs)
plt.xlabel("Months since Jan. 2000")
plt.ylabel("Monthly average of PM10")
plt.title("PM10 levels from 2000 through 2025 (August) by monthly average")
plt.show()

# %% [markdown]
# ## Grahpic 2:  <TYPE>
